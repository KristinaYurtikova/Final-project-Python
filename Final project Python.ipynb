# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\User\\Desktop\\Git\\Homework11 Python\\california_housing_test.csv")

# %%
data
# Out:
#       Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0              1    -117.66     35.60                  14         1740
# 1              2    -117.07     32.71                  26         4151
# 2              3    -117.91     33.61                  27         1797
# 3              4    -117.19     34.05                  33         3007
# 4              5    -119.58     36.83                  13         6135
# ...          ...        ...       ...                 ...          ...
# 3397        3398    -118.33     34.09                  36          654
# 3398        3399    -117.88     34.09                  29         3416
# 3399        3400    -118.32     34.26                  32         3690
# 3400        3401    -118.12     33.80                  35         1835
# 3401        3402    -118.19     33.78                  42         1021
#
#       total_bedrooms  population  households  median_income
# ...

# %%
shape = data.shape

print(f'В данной таблице {shape[1]} столбцов и {shape[0]} строк.')
# Out:
# В данной таблице 9 столбцов и 3402 строк.

# %%
print(f'Столбцы содержат следующие типы данных:')

data.dtypes
# Out:
# Столбцы содержат следующие типы данных:
# Unnamed: 0              int64
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms          int64
# population              int64
# households              int64
# median_income         float64
# dtype: object

# %%
print(f'Здания, возраст которых меньше, чем 35 лет, располагаются на следующих долготах:')

data.loc[data['housing_median_age'] < 35, ['longitude']]
# Out:
# Здания, возраст которых меньше, чем 35 лет, располагаются на следующих долготах:
#       longitude
# 0       -117.66
# 1       -117.07
# 2       -117.91
# 3       -117.19
# 4       -119.58
# ...         ...
# 3392    -122.10
# 3393    -117.52
# 3395    -117.01
# 3398    -117.88
# 3399    -118.32
#
# [2216 rows x 1 columns]

# %%
data[['longitude','latitude']]
# Out:
#       longitude  latitude
# 0       -117.66     35.60
# 1       -117.07     32.71
# 2       -117.91     33.61
# 3       -117.19     34.05
# 4       -119.58     36.83
# ...         ...       ...
# 3397    -118.33     34.09
# 3398    -117.88     34.09
# 3399    -118.32     34.26
# 3400    -118.12     33.80
# 3401    -118.19     33.78
#
# [3402 rows x 2 columns]

# %%
data[(data['total_rooms'] < 2000) & (data['population'] > 1500)]
# Out:
#       Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 12            13    -118.21     33.79                  39         1598
# 18            19    -122.41     37.80                  30         1821
# 69            70    -117.93     34.01                  33         1733
# 100          101    -121.24     36.33                  13         1642
# 120          121    -118.22     33.90                  35         1649
# ...          ...        ...       ...                 ...          ...
# 3151        3152    -118.36     34.22                  37         1512
# 3172        3173    -117.89     33.74                  32         1562
# 3215        3216    -118.23     33.92                  32         1735
# 3332        3333    -119.76     36.71                  29         1745
# 3372        3373    -118.20     33.99                  35         1705
#
#       total_bedrooms  population  households  median_income
# ...

# %%
a = data['population'].max()
b = data['population'].min()

print(f'Максимальное население - {a}, минимальное - {b}.')
# Out:
# Максимальное население - 35682, минимальное - 8.

# %%
# data.columns
print(f"{abs(data.loc[(data['median_income'] > 3),'longitude']).max()} западной долготы")
# Out:
# 124.18 западной долготы

# %%
min_households = data['households'].min()
# data.columns
desired = data.loc[(data['households'] == min_households), 'total_bedrooms'].max()
print(desired)
# Out:
# 7
